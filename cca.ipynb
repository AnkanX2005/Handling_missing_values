# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\\ML-DataSets\\data_science_job.csv")

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 12502                   0.767    Full time course        Graduate         3.0
# 11770                   0.920       no_enrollment        Graduate         4.0
# 17759                   0.939       no_enrollment        Graduate        11.0
# 18806                   0.624       no_enrollment        Graduate         7.0
# 17910                   0.926       no_enrollment     High School        20.0
#
#        training_hours
# 12502            13.0
# 11770            64.0
# 17759            67.0
# 18806            38.0
# 17910            40.0

# %%
new_df = df[cols].dropna()
df[cols].shape, new_df.shape
# Out:
# ((19158, 5), (17182, 5))

# %%
from matplotlib import pyplot as plt

# %%
new_df.hist(bins = 50, density=True, figsize=(12,12))
plt.show()

# %%
import seaborn as sns

# %%
sns.kdeplot(df['training_hours'], color = 'red')
sns.kdeplot(new_df['training_hours'], color = 'blue')
# Out:
# <Axes: xlabel='training_hours', ylabel='Density'>

# %%
sns.kdeplot(df['experience'], color = 'red')
sns.kdeplot(new_df['experience'], color = 'green')
# Out:
# <Axes: xlabel='experience', ylabel='Density'>

# %%
sns.kdeplot(df['city_development_index'], color = 'red')
sns.kdeplot(new_df['city_development_index'], color = 'green')
# Out:
# <Axes: xlabel='city_development_index', ylabel='Density'>
